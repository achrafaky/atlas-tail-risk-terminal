# %% [markdown]
# # 01 — Données MASI & diagnostic de normalité
# **Auteur : Achraf Akiyaf · Master MMSD, FST Tanger**
#
# Question : *la loi normale décrit-elle le risque du MASI ?* (Spoiler à démontrer : non — d'où l'EVT au notebook 02.)

# %% [markdown]
# ## 1. Chargement du CSV (Investing.com)
# ⚠️ Ouvrir d'abord le CSV à l'œil : format des dates ? virgules dans les nombres ?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# TODO : charger data/raw/masi.csv, parser dates + nombres
# masi = ...  (pd.Series, index datetime trié)

# %% [markdown]
# ## 2. Audit qualité & nettoyage
# Documenter CHAQUE correction (traçabilité risk management).

# %%
# TODO : doublons, NaN, prix<=0, variations >20%/jour
# corrections : interpolation SUR LES PRIX (method='time')

# %% [markdown]
# ## 3. Log-rendements & faits stylisés
# r_t = 100·ln(P_t/P_{t-1}). Chercher : queues épaisses, skewness négative, clustering de volatilité.

# %%
# TODO : r = ..., graphique prix + rendements superposés
# stats : moyenne, std, skewness, kurtosis, 5 pires jours (chercher l'actualité de ces dates !)
# test de Jarque-Bera

# %% [markdown]
# ## 4. Histogramme vs loi normale (échelle log)
# Le graphique qui montre les queues épaisses.

# %%
# TODO : hist(density=True) + pdf normale superposée + plt.yscale('log')

# %% [markdown]
# ## 5. VaR gaussienne vs historique + backtest naïf
# VaR99 = quantile 1% changé de signe. Compter les violations réelles vs attendues.

# %%
# TODO : var_gauss, var_hist, comptage violations, graphique final avec points rouges

# %% [markdown]
# ## 6. Conclusion (markdown)
# À rédiger : kurtosis = ?, JB p-value = ?, violations = ? vs attendu = ?, concentrées pendant [crises] → nécessité d'un modèle de queues → notebook 02.

# %%
# (rien à coder ici)
